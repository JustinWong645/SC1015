# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
#Problem 1(a)
houseData = pd.read_csv('train-Copy1.csv') 
houseData.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
#Problem 1(b)
print(houseData.dtypes)

#Ans: Column 1,2,3 is int64, column 4 and 5 is object
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
Problem 1(c)

integerColumns = houseData.select_dtypes(include=['int64']).columns
integerColumns
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# Problem 1(d)
#
# The ones with actual numeric variable are LotArea, BsmtFinSF1, BsmtUnfSF, TotalBsmtSF, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, TotRmsAbvGrd, Fireplaces, GarageCars, GarageArea, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, SalePrice

# %%
#Problem 1(e)

numeric_data = pd.DataFrame(houseData[["LotArea", "BsmtFinSF1", "BsmtUnfSF", "TotalBsmtSF", "1stFlrSF", "2ndFlrSF", "LowQualFinSF", "GrLivArea", "BsmtFullBath", "BsmtHalfBath", "FullBath", "HalfBath", "BedroomAbvGr", "KitchenAbvGr", "TotRmsAbvGrd", "Fireplaces", "GarageCars", "GarageArea", "WoodDeckSF", "OpenPorchSF", "EnclosedPorch", "3SsnPorch", "ScreenPorch", "PoolArea", "MiscVal", "SalePrice"]])
numeric_data
# Out:
#       LotArea  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  1stFlrSF  2ndFlrSF  \
# 0        8450         706        150          856       856       854
# 1        9600         978        284         1262      1262         0
# 2       11250         486        434          920       920       866
# 3        9550         216        540          756       961       756
# 4       14260         655        490         1145      1145      1053
# ...       ...         ...        ...          ...       ...       ...
# 1455     7917           0        953          953       953       694
# 1456    13175         790        589         1542      2073         0
# 1457     9042         275        877         1152      1188      1152
# 1458     9717          49          0         1078      1078         0
# 1459     9937         830        136         1256      1256         0
#
#       LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  ...  GarageCars  \
# ...

# %% [markdown]
# Problem 2

# %%
#Problem 2(a)
numeric_data['SalePrice'].describe().round(2)
# Out:
# count      1460.0
# mean     180921.2
# std       79442.5
# min       34900.0
# 25%      129975.0
# 50%      163000.0
# 75%      214000.0
# max      755000.0
# Name: SalePrice, dtype: float64

# %%
#Problem 2(b)
SalePrice = numeric_data['SalePrice']
f = plt.figure(figsize=(24, 4))
sb.boxplot(data = SalePrice, orient = "h")
# Out:
# <AxesSubplot:>

# %%
f = plt.figure(figsize=(16, 8))
sb.histplot(data = SalePrice)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
f = plt.figure(figsize=(16, 8))
sb.kdeplot(data = SalePrice)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
#Problem 2(c)

numeric_data['LotArea'].describe().round(2)
# Out:
# count      1460.00
# mean      10516.83
# std        9981.26
# min        1300.00
# 25%        7553.50
# 50%        9478.50
# 75%       11601.50
# max      215245.00
# Name: LotArea, dtype: float64

# %%
#Problem 2(d)

LotArea = numeric_data['LotArea']
f = plt.figure(figsize=(24, 4))
sb.boxplot(data = LotArea, orient = "h")
# Out:
# <AxesSubplot:>

# %%
f = plt.figure(figsize=(16, 8))
sb.histplot(data = LotArea)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='Count'>

# %%
f = plt.figure(figsize=(16, 8))
sb.kdeplot(data = LotArea)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='Density'>

# %%
#Problem 2(e)

jointDF = pd.concat([LotArea, SalePrice], axis = 1).reindex(LotArea.index)
jointDF
sb.jointplot(data = jointDF, x = "LotArea", y = "SalePrice", height = 12)

# %%
#Bonus Problem

newdataframe = houseData.select_dtypes(include=['int64', 'float64']).columns
newdataframe
# Out:
# Index(['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
#        'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
actualnewdataframe = pd.DataFrame(houseData[['LotFrontage', 'LotArea',
       'MasVnrArea', 'BsmtFinSF1','BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
       'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF',
       'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea',
       'MiscVal', 'SalePrice']])

actualnewdataframe
# Out:
#       LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 0            65.0     8450       196.0         706           0        150
# 1            80.0     9600         0.0         978           0        284
# 2            68.0    11250       162.0         486           0        434
# 3            60.0     9550         0.0         216           0        540
# 4            84.0    14260       350.0         655           0        490
# ...           ...      ...         ...         ...         ...        ...
# 1455         62.0     7917         0.0           0           0        953
# 1456         85.0    13175       119.0         790         163        589
# 1457         66.0     9042         0.0         275           0        877
# 1458         68.0     9717         0.0          49        1029          0
# 1459         75.0     9937         0.0         830         290        136
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  ...  GarageCars  \
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10048\2118754522.py in <module>
#       1 jointDF = pd.concat([SalePrice, actualnewdataframe], axis = 1).reindex(SalePrice.index)
#       2 jointDF
# ----> 3 sb.jointplot(data = jointDF, x = "SalePrice", y = "actualnewdataframe", height = 12)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, color, height, ratio, space, dropna, xlim, ylim, marginal_ticks, joint_kws, marginal_kws, hue, palette, hue_order, hue_norm, **kwargs)
#    2228
#    2229     # Initialize the JointGrid object
# ...
